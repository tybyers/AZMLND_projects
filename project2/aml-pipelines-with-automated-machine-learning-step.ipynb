# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-130741
# aml-quickstarts-130741
# southcentralus
# 19019985-4709-4996-8830-8568281fc2ff

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'project2'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: project2,
# Workspace: quick-starts-ws-130741)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "proj02-compute"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        print('Found Dataset in Workspace')
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
# Found Dataset in Workspace
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [567d76ca][44001331-276c-42da-99a0-e0c22cdab8af], (This step will run and generate new outputs)
# Submitted PipelineRun 016d1a7d-c152-41db-8bfb-6849cee32fc7
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/project2/runs/016d1a7d-c152-41db-8bfb-6849cee32fc7?wsid=/subscriptions/19019985-4709-4996-8830-8568281fc2ff/resourcegroups/aml-quickstarts-130741/workspaces/quick-starts-ws-130741

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 016d1a7d-c152-41db-8bfb-6849cee32fc7
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/project2/runs/016d1a7d-c152-41db-8bfb-6849cee32fc7?wsid=/subscriptions/19019985-4709-4996-8830-8568281fc2ff/resourcegroups/aml-quickstarts-130741/workspaces/quick-starts-ws-130741
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '016d1a7d-c152-41db-8bfb-6849cee32fc7', 'status': 'Completed', 'startTimeUtc': '2020-12-16T21:09:14.875813Z', 'endTimeUtc': '2020-12-16T21:48:07.934756Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg130741.blob.core.windows.net/azureml/ExperimentRun/dcid.016d1a7d-c152-41db-8bfb-6849cee32fc7/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=PVJlK3KtJ2vSEo%2F7EM1unb32HI5kDt1Oo0zVrnOcLv0%3D&st=2020-12-16T20%3A59%3A36Z&se=2020-12-17T05%3A09%3A36Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg130741.blob.core.windows.net/azureml/ExperimentRun/dcid.016d1a7d-c152-41db-8bfb-6849cee32fc7/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=jL8a%2Bpzo017gecuvwOoX%2FBBdc8ok1ZO%2BgRrxpuskb90%3D&st=2020-12-16T20%3A59%3A36Z&se=2020-12-17T05%3A09%3A36Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg130741.blob.core.windows.net/azureml/ExperimentRun/dcid.016d1a7d-c152-41db-8bfb-6849cee32fc7/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=daUH2M4Se1JnGfsDJnKAFj9MaP4%2F5KvhybyjCWxg%2BdQ%3D&st=2020-12-16T20%3A59%3A36Z&se=2020-12-17T05%3A09%3A36Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/ef28080a-11d5-4eeb-a7fd-4f795faea7ac/metrics_data
# Downloaded azureml/ef28080a-11d5-4eeb-a7fd-4f795faea7ac/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_18  \
# weighted_accuracy                                   [0.7061511074789625]
# f1_score_micro                                      [0.7107738998482549]
# AUC_macro                                           [0.8480949231912004]
# precision_score_weighted                            [0.8778230354906309]
# precision_score_macro                               [0.6008161354662759]
# accuracy                                            [0.7107738998482549]
# recall_score_macro                                  [0.7293936985849694]
# f1_score_macro                                       [0.590447213719585]
# matthews_correlation                                [0.3041485570681034]
# balanced_accuracy                                   [0.7293936985849694]
# average_precision_score_macro                        [0.700254897459451]
# precision_score_micro                               [0.7107738998482549]
# average_precision_score_weighted                    [0.9159663417070354]
# log_loss                                            [0.5729476213847701]
# AUC_weighted                                        [0.8480949231912005]
# average_precision_score_micro                       [0.8246911213787884]
# f1_score_weighted                                   [0.7627178388209338]
# recall_score_micro                                  [0.7107738998482549]
# norm_macro_recall                                  [0.45878739716993877]
# AUC_micro                                           [0.8146183692125606]
# recall_score_weighted                               [0.7107738998482549]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_22  \
# weighted_accuracy                                   [0.9531333625443325]
# f1_score_micro                                      [0.9128983308042489]
# AUC_macro                                           [0.9448491887516277]
# precision_score_weighted                            [0.9080335867085474]
# precision_score_macro                               [0.7860811293290488]
# accuracy                                            [0.9128983308042489]
# recall_score_macro                                  [0.7508386635472644]
# f1_score_macro                                      [0.7668111420906795]
# matthews_correlation                                [0.5357619178216784]
# balanced_accuracy                                   [0.7508386635472644]
# average_precision_score_macro                       [0.8085204474402641]
# precision_score_micro                               [0.9128983308042489]
# average_precision_score_weighted                    [0.9516860732237478]
# log_loss                                           [0.18115151864375498]
# AUC_weighted                                        [0.9448491887516278]
# average_precision_score_micro                        [0.980352027134298]
# f1_score_weighted                                   [0.9100415644605403]
# recall_score_micro                                  [0.9128983308042489]
# norm_macro_recall                                   [0.5016773270945287]
# AUC_micro                                           [0.9793693944704005]
# recall_score_weighted                               [0.9128983308042489]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_21  \
# weighted_accuracy                                   [0.9793227746800656]
# f1_score_micro                                      [0.9004552352048558]
# AUC_macro                                           [0.9304904908242521]
# precision_score_weighted                            [0.8859664258327548]
# precision_score_macro                               [0.8202786854702324]
# accuracy                                            [0.9004552352048558]
# recall_score_macro                                  [0.5827905869626023]
# f1_score_macro                                      [0.6136146528695394]
# matthews_correlation                                [0.3256750549961802]
# balanced_accuracy                                   [0.5827905869626023]
# average_precision_score_macro                        [0.787108791806625]
# precision_score_micro                               [0.9004552352048558]
# average_precision_score_weighted                     [0.945222197717833]
# log_loss                                           [0.22589233807484954]
# AUC_weighted                                        [0.9304904908242522]
# average_precision_score_micro                       [0.9756497344937594]
# f1_score_weighted                                   [0.8719631449552753]
# recall_score_micro                                  [0.9004552352048558]
# norm_macro_recall                                  [0.16558117392520466]
# AUC_micro                                           [0.9744804861368561]
# recall_score_weighted                               [0.9004552352048558]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_25  \
# weighted_accuracy                                   [0.9843450583187134]
# f1_score_micro                                      [0.8880121396054628]
# AUC_macro                                            [0.934308239186288]
# precision_score_weighted                             [0.788565560086672]
# precision_score_macro                               [0.4440060698027314]
# accuracy                                            [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# f1_score_macro                                      [0.4703423886834914]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# average_precision_score_macro                       [0.7951181599264726]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_weighted                    [0.9474863785724514]
# log_loss                                           [0.24604619760082583]
# AUC_weighted                                         [0.934308239186288]
# average_precision_score_micro                       [0.9756340409323144]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_micro                                  [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# AUC_micro                                           [0.9743930772932732]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_36  \
# weighted_accuracy                                   [0.9487570014706295]
# f1_score_micro                                      [0.9068285280728376]
# AUC_macro                                           [0.9287006318456896]
# precision_score_weighted                            [0.9019189767445744]
# precision_score_macro                               [0.7683687347619257]
# accuracy                                            [0.9068285280728376]
# recall_score_macro                                  [0.7379479741482309]
# f1_score_macro                                      [0.7518368170032499]
# matthews_correlation                                [0.5054020053831371]
# balanced_accuracy                                   [0.7379479741482309]
# average_precision_score_macro                       [0.7843208693149157]
# precision_score_micro                               [0.9068285280728376]
# average_precision_score_weighted                    [0.9440479595441246]
# log_loss                                           [0.19634689581676798]
# AUC_weighted                                        [0.9287006318456894]
# average_precision_score_micro                       [0.9757897773133108]
# f1_score_weighted                                   [0.9040310586334096]
# recall_score_micro                                  [0.9068285280728376]
# norm_macro_recall                                  [0.47589594829646176]
# AUC_micro                                           [0.9754779969650986]
# recall_score_weighted                               [0.9068285280728376]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_44  \
# weighted_accuracy                                    [0.956873343874894]
# f1_score_micro                                      [0.9144157814871017]
# AUC_macro                                           [0.9467663986277595]
# precision_score_weighted                            [0.9081323508409725]
# precision_score_macro                               [0.7933699782541717]
# accuracy                                            [0.9144157814871017]
# recall_score_macro                                  [0.7434041496942652]
# f1_score_macro                                       [0.765112631879099]
# matthews_correlation                                [0.5344435240613613]
# balanced_accuracy                                   [0.7434041496942652]
# average_precision_score_macro                       [0.8204134522009083]
# precision_score_micro                               [0.9144157814871017]
# average_precision_score_weighted                    [0.9545330013588291]
# log_loss                                           [0.17904952740917088]
# AUC_weighted                                        [0.9467663986277594]
# average_precision_score_micro                       [0.9811567323388715]
# f1_score_weighted                                   [0.9104373953155903]
# recall_score_micro                                  [0.9144157814871017]
# norm_macro_recall                                   [0.4868082993885303]
# AUC_micro                                           [0.9802282853728346]
# recall_score_weighted                               [0.9144157814871017]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_11  \
# weighted_accuracy                                   [0.6805532353212718]
# f1_score_micro                                      [0.6959028831562974]
# AUC_macro                                            [0.870326685153386]
# precision_score_weighted                            [0.8896065171269141]
# precision_score_macro                               [0.6088240953225678]
# accuracy                                            [0.6959028831562974]
# recall_score_macro                                  [0.7577285786528405]
# f1_score_macro                                      [0.5899359117668977]
# matthews_correlation                                [0.3349452457382647]
# balanced_accuracy                                   [0.7577285786528405]
# average_precision_score_macro                       [0.7305833109552733]
# precision_score_micro                               [0.6959028831562974]
# average_precision_score_weighted                    [0.9251833795394594]
# log_loss                                             [0.511333588346467]
# AUC_weighted                                        [0.8703266851533858]
# average_precision_score_micro                       [0.8466783282598557]
# f1_score_weighted                                    [0.751701610777462]
# recall_score_micro                                  [0.6959028831562974]
# norm_macro_recall                                    [0.515457157305681]
# AUC_micro                                           [0.8371665350314659]
# recall_score_weighted                               [0.6959028831562974]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_41  \
# weighted_accuracy                                   [0.9616076182530957]
# f1_score_micro                                      [0.9062215477996965]
# AUC_macro                                           [0.9292669960192426]
# precision_score_weighted                            [0.8938360320284985]
# precision_score_macro                               [0.7782529523680863]
# accuracy                                            [0.9062215477996965]
# recall_score_macro                                  [0.6831361478344791]
# f1_score_macro                                      [0.7171311575381266]
# matthews_correlation                               [0.45147834419941824]
# balanced_accuracy                                   [0.6831361478344791]
# average_precision_score_macro                       [0.7827935620905802]
# precision_score_micro                               [0.9062215477996965]
# average_precision_score_weighted                    [0.9442416321387344]
# log_loss                                           [0.20239181507590784]
# AUC_weighted                                        [0.9292669960192426]
# average_precision_score_micro                       [0.9766043289729507]
# f1_score_weighted                                    [0.896605592541406]
# recall_score_micro                                  [0.9062215477996965]
# norm_macro_recall                                  [0.36627229566895814]
# AUC_micro                                           [0.9754336938525978]
# recall_score_weighted                               [0.9062215477996965]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_4  \
# weighted_accuracy                                  [0.9843450583187134]
# f1_score_micro                                     [0.8880121396054628]
# AUC_macro                                           [0.874988191098589]
# precision_score_weighted                            [0.788565560086672]
# precision_score_macro                              [0.4440060698027314]
# accuracy                                           [0.8880121396054628]
# recall_score_macro                                                [0.5]
# f1_score_macro                                     [0.4703423886834914]
# matthews_correlation                                              [0.0]
# balanced_accuracy                                                 [0.5]
# average_precision_score_macro                      [0.7191503433687563]
# precision_score_micro                              [0.8880121396054628]
# average_precision_score_weighted                   [0.9232292901133853]
# log_loss                                           [0.2755796237454241]
# AUC_weighted                                       [0.8749881910985889]
# average_precision_score_micro                      [0.9637243217799252]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_micro                                 [0.8880121396054628]
# norm_macro_recall                                                 [0.0]
# AUC_micro                                          [0.9625947255348495]
# recall_score_weighted                              [0.8880121396054628]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_1  ...  \
# weighted_accuracy                                  [0.9537972210153172]  ...
# f1_score_micro                                     [0.9071320182094081]  ...
# AUC_macro                                          [0.9392346349984347]  ...
# precision_score_weighted                           [0.8991976076061607]  ...
# precision_score_macro                              [0.7723958081530135]  ...
# accuracy                                           [0.9071320182094081]  ...
# recall_score_macro                                 [0.7191727470931578]  ...
# f1_score_macro                                     [0.7416848907681176]  ...
# matthews_correlation                                [0.488678780261868]  ...
# balanced_accuracy                                  [0.7191727470931578]  ...
# average_precision_score_macro                      [0.8065229883244922]  ...
# precision_score_micro                              [0.9071320182094081]  ...
# average_precision_score_weighted                   [0.9505970434373063]  ...
# log_loss                                           [0.1874363495858499]  ...
# AUC_weighted                                       [0.9392346349984347]  ...
# average_precision_score_micro                      [0.9791945367231853]  ...
# f1_score_weighted                                  [0.9021127651963996]  ...
# recall_score_micro                                 [0.9071320182094081]  ...
# norm_macro_recall                                 [0.43834549418631563]  ...
# AUC_micro                                          [0.9781770788959222]  ...
# recall_score_weighted                              [0.9071320182094081]  ...
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_15  \
# weighted_accuracy                                   [0.9843450583187134]
# f1_score_micro                                      [0.8880121396054628]
# AUC_macro                                           [0.8828867253129127]
# precision_score_weighted                             [0.788565560086672]
# precision_score_macro                               [0.4440060698027314]
# accuracy                                            [0.8880121396054628]
# recall_score_macro                                                 [0.5]
# f1_score_macro                                      [0.4703423886834914]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# average_precision_score_macro                       [0.6933030853247071]
# precision_score_micro                               [0.8880121396054628]
# average_precision_score_weighted                     [0.918325935639199]
# log_loss                                             [0.257899653001845]
# AUC_weighted                                        [0.8828867253129128]
# average_precision_score_micro                        [0.964492153381863]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_micro                                  [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# AUC_micro                                           [0.9641656899565028]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_27  \
# weighted_accuracy                                   [0.9551064271824635]
# f1_score_micro                                      [0.9122913505311078]
# AUC_macro                                           [0.9327397392224093]
# precision_score_weighted                            [0.9060269508317579]
# precision_score_macro                               [0.7864891147777485]
# accuracy                                            [0.9122913505311078]
# recall_score_macro                                  [0.7398397138448487]
# f1_score_macro                                      [0.7602368688673142]
# matthews_correlation                                [0.5242574455664286]
# balanced_accuracy                                   [0.7398397138448487]
# average_precision_score_macro                       [0.8087023547268216]
# precision_score_micro                               [0.9122913505311078]
# average_precision_score_weighted                    [0.9499542073055386]
# log_loss                                            [0.3228471217286364]
# AUC_weighted                                        [0.9327397392224092]
# average_precision_score_micro                       [0.9774090869774331]
# f1_score_weighted                                   [0.9084088618605763]
# recall_score_micro                                  [0.9122913505311078]
# norm_macro_recall                                   [0.4796794276896974]
# AUC_micro                                           [0.9767612214211536]
# recall_score_weighted                               [0.9122913505311078]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_32  \
# weighted_accuracy                                    [0.840649477553501]
# f1_score_micro                                       [0.844309559939302]
# AUC_macro                                           [0.9243822786826639]
# precision_score_weighted                            [0.9178602947810399]
# precision_score_macro                                [0.695556241600988]
# accuracy                                             [0.844309559939302]
# recall_score_macro                                   [0.859051731323875]
# f1_score_macro                                      [0.7318234974105472]
# matthews_correlation                                [0.5299615348986177]
# balanced_accuracy                                    [0.859051731323875]
# average_precision_score_macro                       [0.7558260882153456]
# precision_score_micro                                [0.844309559939302]
# average_precision_score_weighted                    [0.9367180544917935]
# log_loss                                            [0.4016899169760293]
# AUC_weighted                                         [0.924382278682664]
# average_precision_score_micro                       [0.8847601937251316]
# f1_score_weighted                                   [0.8666064692409249]
# recall_score_micro                                   [0.844309559939302]
# norm_macro_recall                                     [0.71810346264775]
# AUC_micro                                           [0.9116926598216362]
# recall_score_weighted                                [0.844309559939302]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_45  \
# weighted_accuracy                                   [0.9640987546387602]
# f1_score_micro                                      [0.9156297420333839]
# AUC_macro                                           [0.9463227544100459]
# precision_score_weighted                            [0.9067348031777203]
# precision_score_macro                               [0.8069788441692467]
# accuracy                                            [0.9156297420333839]
# recall_score_macro                                   [0.720405040687454]
# f1_score_macro                                      [0.7539448971522388]
# matthews_correlation                                [0.5202295056580717]
# balanced_accuracy                                    [0.720405040687454]
# average_precision_score_macro                       [0.8192281050921841]
# precision_score_micro                               [0.9156297420333839]
# average_precision_score_weighted                    [0.9542217486409112]
# log_loss                                            [0.2019698709018305]
# AUC_weighted                                         [0.946322754410046]
# average_precision_score_micro                       [0.9809326963428132]
# f1_score_weighted                                   [0.9087289287363227]
# recall_score_micro                                  [0.9156297420333839]
# norm_macro_recall                                  [0.44081008137490807]
# AUC_micro                                           [0.9799891775140979]
# recall_score_weighted                               [0.9156297420333839]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_9  \
# weighted_accuracy                                  [0.7143493111979725]
# f1_score_micro                                     [0.7168437025796661]
# AUC_macro                                          [0.8324585484405767]
# precision_score_weighted                           [0.8765394635250148]
# precision_score_macro                              [0.6010050095862453]
# accuracy                                           [0.7168437025796661]
# recall_score_macro                                 [0.7268906745800199]
# f1_score_macro                                     [0.5933104551571741]
# matthews_correlation                               [0.3027678632945351]
# balanced_accuracy                                  [0.7268906745800199]
# average_precision_score_macro                      [0.7108984111077482]
# precision_score_micro                              [0.7168437025796661]
# average_precision_score_weighted                   [0.9137755098024067]
# log_loss                                           [0.5569509841898442]
# AUC_weighted                                       [0.8324585484405767]
# average_precision_score_micro                      [0.8108632631206174]
# f1_score_weighted                                  [0.7672501653219937]
# recall_score_micro                                 [0.7168437025796661]
# norm_macro_recall                                 [0.45378134916003976]
# AUC_micro                                          [0.8313519587548155]
# recall_score_weighted                              [0.7168437025796661]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_13  \
# weighted_accuracy                                   [0.9766010009385309]
# f1_score_micro                                      [0.9062215477996965]
# AUC_macro                                           [0.9308878256246677]
# precision_score_weighted                            [0.8929725418691179]
# precision_score_macro                                [0.822098675416211]
# accuracy                                            [0.9062215477996965]
# recall_score_macro                                  [0.6227454260188535]
# f1_score_macro                                      [0.6650154684677185]
# matthews_correlation                                [0.3976739324324451]
# balanced_accuracy                                   [0.6227454260188535]
# average_precision_score_macro                       [0.7985126174047921]
# precision_score_micro                               [0.9062215477996965]
# average_precision_score_weighted                     [0.947605275820125]
# log_loss                                           [0.33655623030329523]
# AUC_weighted                                        [0.9308878256246675]
# average_precision_score_micro                       [0.9766643355999638]
# f1_score_weighted                                    [0.885603431576398]
# recall_score_micro                                  [0.9062215477996965]
# norm_macro_recall                                  [0.24549085203770704]
# AUC_micro                                           [0.9758990146932517]
# recall_score_weighted                               [0.9062215477996965]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_20  \
# weighted_accuracy                                    [0.955148852498673]
# f1_score_micro                                      [0.9125948406676783]
# AUC_macro                                           [0.9424512871239443]
# precision_score_weighted                            [0.9064419404986112]
# precision_score_macro                               [0.7872528061629692]
# accuracy                                            [0.9125948406676783]
# recall_score_macro                                  [0.7411947273949842]
# f1_score_macro                                      [0.7613817409356443]
# matthews_correlation                                [0.5264365575296669]
# balanced_accuracy                                   [0.7411947273949842]
# average_precision_score_macro                       [0.8131628841963428]
# precision_score_micro                               [0.9125948406676783]
# average_precision_score_weighted                    [0.9524536910133203]
# log_loss                                           [0.18386077817913915]
# AUC_weighted                                        [0.9424512871239444]
# average_precision_score_micro                       [0.9800107530929907]
# f1_score_weighted                                   [0.9087900123862012]
# recall_score_micro                                  [0.9125948406676783]
# norm_macro_recall                                   [0.4823894547899683]
# AUC_micro                                           [0.9790159827392864]
# recall_score_weighted                               [0.9125948406676783]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_23  \
# weighted_accuracy                                    [0.954224463495085]
# f1_score_micro                                      [0.9122913505311078]
# AUC_macro                                           [0.9453011686644549]
# precision_score_weighted                            [0.9065237929615331]
# precision_score_macro                               [0.7856414593106926]
# accuracy                                            [0.9122913505311078]
# recall_score_macro                                  [0.7433921092457678]
# f1_score_macro                                      [0.7621206659537194]
# matthews_correlation                                 [0.527343824348664]
# balanced_accuracy                                   [0.7433921092457678]
# average_precision_score_macro                       [0.8148761708639233]
# precision_score_micro                               [0.9122913505311078]
# average_precision_score_weighted                    [0.9531295963042634]
# log_loss                                            [0.1794115673144867]
# AUC_weighted                                        [0.9453011686644548]
# average_precision_score_micro                       [0.9805426494262558]
# f1_score_weighted                                   [0.9087923391639493]
# recall_score_micro                                  [0.9122913505311078]
# norm_macro_recall                                  [0.48678421849153564]
# AUC_micro                                           [0.9795946863896877]
# recall_score_weighted                               [0.9122913505311078]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_34  \
# weighted_accuracy                                   [0.9524999721188641]
# f1_score_micro                                      [0.9104704097116844]
# AUC_macro                                           [0.9442545758335232]
# precision_score_weighted                            [0.9048930721424753]
# precision_score_macro                               [0.7797943689453914]
# accuracy                                            [0.9104704097116844]
# recall_score_macro                                  [0.7411826869464866]
# f1_score_macro                                      [0.7584448322812782]
# matthews_correlation                                [0.5195442529553999]
# balanced_accuracy                                   [0.7411826869464866]
# average_precision_score_macro                       [0.8129296078280362]
# precision_score_micro                               [0.9104704097116844]
# average_precision_score_weighted                    [0.9525965806282052]
# log_loss                                           [0.17953984826011166]
# AUC_weighted                                        [0.9442545758335231]
# average_precision_score_micro                       [0.9803278107514134]
# f1_score_weighted                                   [0.9071553913821001]
# recall_score_micro                                  [0.9104704097116844]
# norm_macro_recall                                   [0.4823653738929732]
# AUC_micro                                           [0.9793498679426453]
# recall_score_weighted                               [0.9104704097116844]
#
#                                  ef28080a-11d5-4eeb-a7fd-4f795faea7ac_33
# weighted_accuracy                                   [0.9584920593949829]
# f1_score_micro                                      [0.9007587253414264]
# AUC_macro                                           [0.9223474428865956]
# precision_score_weighted                            [0.8867247421523131]
# precision_score_macro                               [0.7576423859848216]
# accuracy                                            [0.9007587253414264]
# recall_score_macro                                  [0.6682189583344911]
# f1_score_macro                                      [0.6997541387206018]
# matthews_correlation                               [0.41636682765647687]
# balanced_accuracy                                   [0.6682189583344911]
# average_precision_score_macro                       [0.7631569010354631]
# precision_score_micro                               [0.9007587253414264]
# average_precision_score_weighted                    [0.9388942469105774]
# log_loss                                            [0.2256938448626899]
# AUC_weighted                                        [0.9223474428865958]
# average_precision_score_micro                       [0.9677154743876325]
# f1_score_weighted                                   [0.8903953583012578]
# recall_score_micro                                  [0.9007587253414264]
# norm_macro_recall                                  [0.33643791666898215]
# AUC_micro                                            [0.969904554884971]
# recall_score_weighted                               [0.9007587253414264]
#
# [21 rows x 44 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/ef28080a-11d5-4eeb-a7fd-4f795faea7ac/model_data
# Downloaded azureml/ef28080a-11d5-4eeb-a7fd-4f795faea7ac/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                  reg_lambda=0.47368421052631576,
#                                                                                                                                  silent=True,
#                                                                                                                                  subsample=0.3963157894736842,
#                                                                                                                                  subsample_for_bin=200000,
#                                                                                                                                  subsample_freq=0,
#                                                                                                                                  verbose=-10))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.2857142857142857,
#                                                                                          0.21428571428571427,
#                                                                                          0.2857142857142857,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142,
#                                                                                          0.07142857142857142]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('23',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='goss',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=0.1988888888888889,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_bin=310,
#                                                                                  max_depth=9,
#                                                                                  min_child_samples=103,
#                                                                                  mi...
#                                                                                  objective=None,
#                                                                                  random_state=None,
#                                                                                  reg_alpha=0.10526315789473684,
#                                                                                  reg_lambda=0.47368421052631576,
#                                                                                  silent=True,
#                                                                                  subsample=0.3963157894736842,
#                                                                                  subsample_for_bin=200000,
#                                                                                  subsample_freq=0,
#                                                                                  verbose=-10))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.2857142857142857, 0.21428571428571427,
#                                          0.2857142857142857, 0.07142857142857142,
#                                          0.07142857142857142,
#                                          0.07142857142857142]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_705204c4_3fe8_11eb_b0fe_000d3aee99c0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_705204c4_3fe8_11eb_b0fe_000d3aee99c0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row0_col0" class="data row0 col0" >28680</td>
#                         <td id="T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row0_col1" class="data row0 col1" >578</td>
#             </tr>
#             <tr>
#                         <th id="T_705204c4_3fe8_11eb_b0fe_000d3aee99c0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row1_col0" class="data row1 col0" >1281</td>
#                         <td id="T_705204c4_3fe8_11eb_b0fe_000d3aee99c0row1_col1" class="data row1 col1" >2411</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 3163418f-08b2-4eb4-baa2-bcb557dacfef,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/19019985-4709-4996-8830-8568281fc2ff/resourceGroups/aml-quickstarts-130741/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-130741/PipelineRuns/PipelineSubmit/3163418f-08b2-4eb4-baa2-bcb557dacfef)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  47c41975-7179-426a-acb6-f6510a4ca96a

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
